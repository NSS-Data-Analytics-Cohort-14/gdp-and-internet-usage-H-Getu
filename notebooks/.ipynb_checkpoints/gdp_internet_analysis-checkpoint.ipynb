# %% [markdown]
# ## This is a example of how you will be doing projects in python.
# ### Use markdown cells -OR- comments in cells to place AT LEAST the question number you are working on.

# %% [markdown]
# 3.	Import the required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 4. Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2023  1992.424394              NaN
# 1     Afghanistan  2022  1981.710168              NaN
# 2     Afghanistan  2021  2144.166570              NaN
# 3     Afghanistan  2020  2769.685745              NaN
# 4     Afghanistan  2019  2927.245144              NaN

# %%
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN

# %% [markdown]
# 5. How many rows and columns are in `gdp_df`? What are the data types of each column?

# %%
print(len(gdp_df))
# Out:
# 8219

# %%
print(len(gdp_df.columns))
# Out:
# 4

# %% [markdown]
# 6. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %%
gdp_df=gdp_df.drop("Value Footnotes",axis=1)
gdp_df=gdp_df.rename(columns={"Country or Area":"Country","Year":"Year","Value":"GDP_Per_Capita"})
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2023     1992.424394
# 1  Afghanistan  2022     1981.710168
# 2  Afghanistan  2021     2144.166570
# 3  Afghanistan  2020     2769.685745
# 4  Afghanistan  2019     2927.245144

# %% [markdown]
# 7. How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?

# %%
print(gdp_df.Year.min())
print(gdp_df.Year.max())
print(gdp_df.Year.max()-gdp_df.Year.min()+1)
# Out:
# 1990
# 2023
# 34

# %%
country_count=gdp_df["Country"].value_counts()==34

all_year_countries=country_count[country_count==True]
print("Countries with all year data :-",len(all_year_countries))

some_year_countries=country_count[country_count==False]
print("Countries with missing data :-",len(some_year_countries))
# Out:
# Countries with all year data :- 228
# Countries with missing data :- 19

# %% [markdown]
# 8. In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %%
gdp_df.hist("GDP_Per_Capita",bins=50,edgecolor="black", grid=False, color="Green")
# Out:
# array([[<Axes: title={'center': 'GDP_Per_Capita'}>]], dtype=object)

# %%
sns.kdeplot(gdp_df["GDP_Per_Capita"], fill=True, color="green",bw_method=0.05)
plt.title("Density plot using seaborn",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Density plot using seaborn')

# %%
plt.boxplot(gdp_df["GDP_Per_Capita"])
plt.title("boxplot using matplotlib", fontsize=15)
# Out:
# Text(0.5, 1.0, 'boxplot using matplotlib')

# %%
sns.violinplot(gdp_df["GDP_Per_Capita"])
plt.title("Violin plot using seaborn", size=15)
# Out:
# Text(0.5, 1.0, 'Violin plot using seaborn')

# %% [markdown]
# 9. What was the median GDP per capita value in 2020?

# %%
gdp_2020=gdp_df[gdp_df["Year"]==2020]
gdp_2020_mean=gdp_2020["GDP_Per_Capita"].mean()
print(gdp_2020_mean)
# Out:
# 23044.942555569738

# %% [markdown]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
# 	* A boxplot
# 	* A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# 	* A scatterplot
# 	* A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
gdp_df_decades=gdp_df[gdp_df.Year.isin([1990,2000,2010,2020])]

# %%
sns.boxplot(x=gdp_df_decades.Year,y=gdp_df_decades.GDP_Per_Capita)
plt.title("box plot", size = 15)
plt.show()

# %%
sns.barplot(x=gdp_df_decades.Year,y=gdp_df_decades.GDP_Per_Capita,errorbar=("ci", 0))
plt.title("Bar chart",size=15)
# Out:
# Text(0.5, 1.0, 'Bar chart')

# %%
sns.scatterplot(x=gdp_df_decades.Year,y=gdp_df_decades.GDP_Per_Capita,hue=gdp_df_decades.Year,palette=['green','orange','blue','purple'],s=25)
plt.title("scatter plot")
plt.show()

# %%
sns.regplot(x='Year', y='GDP_Per_Capita',data=gdp_df_decades)
plt.title("scatter plot with trendline")
plt.show()

# %% [markdown]
# gdp per capita increased 1990 through 2020

# %% [markdown]
# 11. Which country was the first to have a GDP per capita greater than $100,000?

# %%
k_gdp=gdp_df[
        gdp_df.GDP_Per_Capita>100000]
k_gdp=k_gdp[k_gdp.Year==k_gdp.Year.min()]
print(k_gdp)
# Out:
#                    Country  Year  GDP_Per_Capita
# 974                 Brunei  1990   118163.683198
# 7827  United Arab Emirates  1990   108057.042464

# %% [markdown]
# 12. Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
gdp_2020=gdp_df[gdp_df.Year==2020]
gdp_2020_max=gdp_2020[gdp_2020.GDP_Per_Capita==gdp_2020.GDP_Per_Capita.max()]
print(gdp_2020_max)
# Out:
#          Country  Year  GDP_Per_Capita
# 4426  Luxembourg  2020   128256.560341

# %%
country_data_h=gdp_df[gdp_df.Country.isin(gdp_2020_max.Country)]
sns.lineplot(x='Year',y='GDP_Per_Capita',data=country_data_h)
plt.title(set(country_data_h.Country))
# Out:
# Text(0.5, 1.0, "{'Luxembourg'}")

# %% [markdown]
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset. **Bonus question:** Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?

# %%
gdp_2020_min=gdp_2020[gdp_2020.GDP_Per_Capita==gdp_2020.GDP_Per_Capita.min()]

country_data_l=gdp_df[gdp_df.Country.isin(gdp_2020_min.Country)]
sns.lineplot(x='Year',y='GDP_Per_Capita',data=country_data_l)
plt.title(set(country_data_l.Country))
# Out:
# Text(0.5, 1.0, "{'Burundi'}")

# %%
all_countries=dict(gdp_df.groupby('Year')['GDP_Per_Capita'].mean())

x=list(all_countries.keys())
y=list(all_countries.values())

plt.plot(x,
         y,
         label="all_countries_mean",
        color='orange')
plt.plot(country_data_l.Year, 
         country_data_l.GDP_Per_Capita,
         label="least_gdp",
         color="blue")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Gdp_per_capita")
plt.title(f'world mean gdp vs {set(country_data_l.Country)} gdp trend')
plt.show()

# %% [markdown]
# The general trend for all countries is that the mean gdp_per_Capita increases over time; whereas Burundi's gdp_per_capita decreases over time

# %%
gdp_1990 = gdp_df[gdp_df['Year'] == 1990].set_index('Country')['GDP_Per_Capita']
gdp_2020 = gdp_df[gdp_df['Year'] == 2020].set_index('Country')['GDP_Per_Capita']
merged_gdp = pd.concat([gdp_1990, gdp_2020], axis=1, keys=['1990', '2020'])
countries_decline = merged_gdp[merged_gdp['1990'] > merged_gdp['2020']]
print(countries_decline)
# Out:
#                                                    1990          2020
# Country
# Aruba                                      34579.220640  28521.688852
# Barbados                                   16976.761648  15749.038017
# Brunei                                    118163.683198  80280.897948
# Burundi                                     1396.077627    833.920257
# Central African Republic                    1481.252551   1136.570530
# Congo                                       8699.526839   6350.509134
# Dem. Rep. Congo                             2172.001597   1277.632863
# Fragile and conflict affected situations    6062.707946   5271.014406
# Gabon                                      23884.810700  18681.484074
# Haiti                                       3946.365646   3229.475544
# Kyrgyz Republic                             6095.681086   5537.795885
# Liberia                                     1866.405481   1497.376924
# ...

# %% [markdown]
# 14. Read in the internet use dataset into a DataFrame named `internet_df`. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.

# %%
internet_df = pd.read_csv('../data/internet_use.csv',nrows = 6083)

# %%
internet_df.head()
internet_df.tail()
# Out:
#      Country or Area  Year     Value Value Footnotes
# 6078        Zimbabwe  1997  0.033080             NaN
# 6079        Zimbabwe  1996  0.016790             NaN
# 6080        Zimbabwe  1995  0.007684             NaN
# 6081        Zimbabwe  1994  0.001739             NaN
# 6082        Zimbabwe  1990  0.000000             NaN

# %% [markdown]
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6083 non-null   object
#  1   Year             6083 non-null   int64
#  2   Value            6083 non-null   float64
#  3   Value Footnotes  2826 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 190.2+ KB

# %% [markdown]
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'

# %%
del(internet_df['Value Footnotes'])

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']

# %% [markdown]
# 16. Look at the number of observations in this dataset per year. What do you notice?

# %%
internet_df['Year'].value_counts()
# Out:
# Year
# 1990    226
# 2007    217
# 2011    214
# 2008    214
# 2009    214
# 2002    214
# 2006    212
# 2001    212
# 2005    212
# 2004    210
# 2000    210
# 2010    209
# 2012    209
# 2003    208
# 1999    207
# 2016    206
# 2017    205
# 2014    204
# 2015    203
# 2013    203
# 1998    195
# 1997    188
# 2021    186
# 2020    186
# 2019    185
# 2022    184
# 1996    177
# 2018    174
# 1995    141
# 1994     92
# 1993     66
# 1992     50
# 1991     39
# 2023     11
# Name: count, dtype: int64

# %% [markdown]
# 17. What is the first year to have a non-zero internet users percentage value?

# %%
non_zero_pct = internet_df[internet_df['Internet_Users_Pct'] > 0]
min_year = non_zero_pct.groupby('Country')['Year'].min()
print(min_year)
# Out:
# Country
# Afghanistan            2001
# Albania                1995
# Algeria                1994
# Andorra                1996
# Angola                 1996
#                        ...
# Virgin Islands (US)    1994
# Wallis and Futuna      1999
# Yemen                  1996
# Zambia                 1994
# Zimbabwe               1994
# Name: Year, Length: 227, dtype: int64

# %% [markdown]
# 18. How does the distribution of internet users percent differ for 2000 and 2014?

# %%
internet_df_2000 = internet_df[internet_df['Year'] == 2000].set_index('Country')['Internet_Users_Pct']
internet_df_2014 = internet_df[internet_df['Year'] == 2014].set_index('Country')['Internet_Users_Pct']
internet_combined = pd.concat([internet_df_2000,internet_df_2014], axis = 1, keys =['2000','2014'])
Avg_difference = (internet_combined['2014']-internet_combined['2000']).mean()
print(f'The Internet_Users_Pct for all countries from 2000 to 2014 increased by an avg of {Avg_difference} percent.')
# Out:
# The Internet_Users_Pct for all countries from 2000 to 2014 increased by an avg of 37.47148912969231 percent.

# %% [markdown]
# 19. For how many countries was the percentage of internet users below 5% in 2014?

# %%
internet_user_2014 = internet_df[np.logical_and(internet_df['Year'] == 2014,internet_df['Internet_Users_Pct'] < 5)]
print(f'The number of countries with internet users less than 5% in 2014 is {internet_user_2014['Country'].count()}.')
# Out:
# The number of countries with internet users less than 5% in 2014 is 10.

# %% [markdown]
# 20. Merge the two DataFrames to one. Do this in a way that keeps **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`. Look at the first and last few rows to confirm that it merged correctly.

# %%
gdp_and_internet_use = pd.merge(gdp_df,internet_df, on =('Country', 'Year'), how = 'inner')
gdp_and_internet_use.head()
gdp_and_internet_use.tail()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4798  Zimbabwe  1997     4304.406272            0.033080
# 4799  Zimbabwe  1996     4271.479930            0.016790
# 4800  Zimbabwe  1995     3935.280057            0.007684
# 4801  Zimbabwe  1994     3965.730986            0.001739
# 4802  Zimbabwe  1990     4013.299059            0.000000

# %% [markdown]
# 21. Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. What do you notice?

# %%
gdp_and_internet_2014 = gdp_and_internet_use[gdp_and_internet_use['Year'] == 2014]
gdp_and_internet_sorted = gdp_and_internet_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
gdp_and_internet_top3 = gdp_and_internet_sorted.head(3)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1992  Iceland  2014    57981.199448             98.1580
# 540   Bermuda  2014    92298.387811             96.8000
# 3268   Norway  2014    84753.668395             96.3005

# %%
gdp_top3 = gdp_and_internet_use[gdp_and_internet_use['Country'].isin(gdp_and_internet_top3['Country'])]
sns.lineplot(x = 'Year', y = 'GDP_Per_Capita', data = gdp_top3, hue = 'Country' )
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# 22. Subset `gdp_and_internet_use` to just the year 2014. Save this as a new dataframe named `gdp_and_internet_use_2014`.

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use[gdp_and_internet_use['Year'] == 2014]
gdp_and_internet_use_2014.head()
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5    Afghanistan  2014     3017.942544              7.0000
# 27       Albania  2014    12788.747231             54.3000
# 56       Algeria  2014    15073.762940             29.5000
# 85       Andorra  2014    59929.244467             86.1000
# 112       Angola  2014    10250.592404             21.3623

# %% [markdown]
# 23. Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
sns.regplot(data = gdp_and_internet_use_2014, x = 'Internet_Users_Pct', y = 'GDP_Per_Capita')
plt.yticks([0,20000,40000,60000,80000,100000,120000],['0','20k','40k','60k','80k','100k','120k'])
plt.show()

# %% [markdown]
# 24. **Stretch Question:** Use the `qcut` function from pandas (https://pandas.pydata.org/docs/reference/api/pandas.qcut.html) to divide countries in `gdp_per_capita_2014` into three groups based on their GDP per capita values. Label these groups as "Low", "Medium", and "High". Put these labels in a new column, named "GDP_group".
